# %% [markdown]
# <a href="https://colab.research.google.com/github/tonycico0912/ChatGPT_Python/blob/main/TransactionPrice_%EC%B5%9C%EC%A2%852.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PublicDataReader --upgrade

import pandas as pd
from PublicDataReader import TransactionPrice
from openpyxl import Workbook
from google.colab import files
import math

# 서비스 키 설정
service_key = "famiixwEif4c2hlW%2FlclPVLh%2FISGVok55K38Mh6MxXwEL6Jnx%2BAwpZM7QTGO3JejqOX9PKZ%2BVkg%2F2FLihXcPXA%3D%3D"
api = TransactionPrice(service_key)

# 파일 업로드
uploaded = files.upload()

# 엑셀 파일에서 시군구 코드 읽기
codes_df = pd.read_excel(next(iter(uploaded.keys())), sheet_name='시군구코드')
codes = codes_df.iloc[2:425, 1].values  # 시군구 코드
names = codes_df.iloc[2:425, 2].values  # 시군구 이름
sido_names = codes_df.iloc[2:425, 0].values  # 시도 이름

# 시도명과 번호 출력
sido_set = sorted(set(sido_names))
for i, name in enumerate(sido_set):
    print(f'{i+1}. {name}')

# 사용자에게 시도명 선택 받기
sido_index = int(input("Enter the number of the sido for download: ")) - 1
selected_sido = sido_set[sido_index]

# 선택된 시도에 속하는 시군구 코드와 이름 선택
selected_codes = [code for code, name in zip(codes, sido_names) if name == selected_sido]
selected_names = [name for name, sido_name in zip(names, sido_names) if sido_name == selected_sido]

# 각 시군구 코드에 대해 조회하고 결과를 워크북으로 저장
for i in range(math.ceil(len(selected_codes) / 40)):
    start = i * 40
    end = min((i + 1) * 40, len(selected_codes))
    result = pd.DataFrame()

    for code, name in zip(selected_codes[start:end], selected_names[start:end]):
        df = api.get_data(
            property_type="아파트",
            trade_type="매매",
            sigungu_code=str(code),
            year_month="202212",
        )
        result = pd.concat([result, df])

    result.to_excel(f'{selected_sido}_202212_{i+1}.xlsx')

    # 파일 다운로드
    files.download(f'{selected_sido}_202212_{i+1}.xlsx')
# Out:
# ...
#      <input type="file" id="files-5659fc46-c526-42d9-a35f-0ecc3eeb03e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5659fc46-c526-42d9-a35f-0ecc3eeb03e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install PublicDataReader --upgrade

import pandas as pd
from PublicDataReader import TransactionPrice
from openpyxl import Workbook
from google.colab import files
import math

# 서비스 키 설정
service_key = "famiixwEif4c2hlW%2FlclPVLh%2FISGVok55K38Mh6MxXwEL6Jnx%2BAwpZM7QTGO3JejqOX9PKZ%2BVkg%2F2FLihXcPXA%3D%3D"
api = TransactionPrice(service_key)

# 파일 업로드
uploaded = files.upload()

# 엑셀 파일에서 시군구 코드 읽기
codes_df = pd.read_excel(next(iter(uploaded.keys())), sheet_name='시군구코드')
codes = codes_df.iloc[2:425, 1].values  # 시군구 코드
names = codes_df.iloc[2:425, 2].values  # 시군구 이름
sido_names = codes_df.iloc[2:425, 0].values  # 시도 이름

# 시도명과 번호 출력
sido_set = sorted(set(sido_names))
for i, name in enumerate(sido_set):
    print(f'{i+1}. {name}')

# 사용자에게 시도명 선택 받기
sido_index = int(input("Enter the number of the sido for download: ")) - 1
selected_sido = sido_set[sido_index]

# 선택된 시도에 속하는 시군구 코드와 이름 선택
selected_codes = [code for code, name in zip(codes, sido_names) if name == selected_sido]
selected_names = [name for name, sido_name in zip(names, sido_names) if sido_name == selected_sido]

# 부동산 유형 리스트
property_types = ["아파트", "분양입주권"]

# 각 부동산 유형에 대해 조회하고 결과를 워크북으로 저장
for property_type in property_types:
    for i in range(math.ceil(len(selected_codes) / 40)):
        start = i * 40
        end = min((i + 1) * 40, len(selected_codes))
        result = pd.DataFrame()

        for code, name in zip(selected_codes[start:end], selected_names[start:end]):
            try:
                df = api.get_data(
                    property_type=property_type,
                    trade_type="매매",
                    sigungu_code=str(code),
                    year_month="202212",
                )
                result = pd.concat([result, df])
            except Exception as e:
                print(f"Failed to fetch data for {property_type} in {name}. Error: {e}")

        result.to_excel(f'{selected_sido}_{property_type}_202212_{i+1}.xlsx')

        # 파일 다운로드
        files.download(f'{selected_sido}_{property_type}_202212_{i+1}.xlsx')

# %%
# !pip install PublicDataReader --upgrade

import pandas as pd
from PublicDataReader import TransactionPrice
from openpyxl import Workbook
from google.colab import files
import math

# 서비스 키 설정
service_key = "famiixwEif4c2hlW%2FlclPVLh%2FISGVok55K38Mh6MxXwEL6Jnx%2BAwpZM7QTGO3JejqOX9PKZ%2BVkg%2F2FLihXcPXA%3D%3D"
api = TransactionPrice(service_key)

# 파일 업로드
uploaded = files.upload()

# 엑셀 파일에서 시군구 코드 읽기
codes_df = pd.read_excel(next(iter(uploaded.keys())), sheet_name='시군구코드')
codes = codes_df.iloc[2:425, 1].values  # 시군구 코드
names = codes_df.iloc[2:425, 2].values  # 시군구 이름
sido_names = codes_df.iloc[2:425, 0].values  # 시도 이름

# 시도명과 번호 출력
sido_set = sorted(set(sido_names))
for i, name in enumerate(sido_set):
    print(f'{i+1}. {name}')

# 사용자에게 시도명 선택 받기
sido_index = int(input("Enter the number of the sido for download: ")) - 1
selected_sido = sido_set[sido_index]

# 선택된 시도에 속하는 시군구 코드와 이름 선택
selected_codes = [code for code, name in zip(codes, sido_names) if name == selected_sido]
selected_names = [name for name, sido_name in zip(names, sido_names) if sido_name == selected_sido]

# 부동산 유형 리스트
property_types = ["아파트", "오피스텔","분양입주권"]

# 각 부동산 유형에 대해 조회하고 결과를 워크북으로 저장
for property_type in property_types:
    for i in range(math.ceil(len(selected_codes) / 40)):
        start = i * 40
        end = min((i + 1) * 40, len(selected_codes))
        result = pd.DataFrame()

        for code, name in zip(selected_codes[start:end], selected_names[start:end]):
            df = api.get_data(
                property_type=property_type,
                trade_type="매매",
                sigungu_code=str(code),
                year_month="202212",
            )
            result = pd.concat([result, df])

        result.to_excel(f'{selected_sido}_{property_type}_202212_{i+1}.xlsx')

        # 파일 다운로드
        files.download(f'{selected_sido}_{property_type}_202212_{i+1}.xlsx')
# Out:
# ...
#      <input type="file" id="files-80f18be1-fc79-485e-81db-292c10c44547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80f18be1-fc79-485e-81db-292c10c44547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
