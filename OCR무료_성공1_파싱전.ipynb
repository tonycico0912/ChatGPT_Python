# %% [markdown]
# <a href="https://colab.research.google.com/github/tonycico0912/ChatGPT_Python/blob/main/OCR%EB%AC%B4%EB%A3%8C_%EC%84%B1%EA%B3%B51_%ED%8C%8C%EC%8B%B1%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 11.7 MB/s eta 0:00:00
# ...

# %%
import easyocr
from PIL import Image
import matplotlib.pyplot as plt

# OCR 엔진 생성 (한국어와 영어를 지원하도록 설정)
reader = easyocr.Reader(['ko','en'])

# 이미지 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 파일명을 가져옵니다.
filename = next(iter(uploaded))

# 이미지를 읽어옵니다.
image = Image.open(filename)

# OCR 적용
result = reader.readtext(image)

# 결과 출력
print(result)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.1% Complete
#      <input type="file" id="files-30de19ca-2bec-4f5c-aa4c-c50b2a7af8fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30de19ca-2bec-4f5c-aa4c-c50b2a7af8fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# ...

# %%
# !pip install easyocr

import easyocr
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# OCR 엔진 생성 (한국어와 영어를 지원하도록 설정)
reader = easyocr.Reader(['ko','en'])

# 이미지 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 파일명을 가져옵니다.
filename = next(iter(uploaded))

# 이미지를 읽어옵니다.
image = Image.open(filename)

# 이미지를 numpy 배열로 변환합니다.
image_np = np.array(image)

# OCR 적용
result = reader.readtext(image_np)

# 결과 출력
print(result)
# Out:
# ...
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
#      <input type="file" id="files-d861a253-1c85-4c0e-a5df-491a32e21a7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d861a253-1c85-4c0e-a5df-491a32e21a7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install easyocr

import easyocr
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# OCR 엔진 생성 (한국어와 영어를 지원하도록 설정)
reader = easyocr.Reader(['ko','en'])

# 이미지 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 파일명을 가져옵니다.
filename = next(iter(uploaded))

# 이미지를 읽어옵니다.
image = Image.open(filename)

# 이미지를 numpy 배열로 변환합니다.
image_np = np.array(image)

# OCR 적용
result = reader.readtext(image_np)

# 결과 출력
for res in result:
    coordinates, text, confidence = res
    print(f"Coordinates: {coordinates}")
    print(f"Text: {text}")
    print(f"Confidence: {confidence}\n")
# Out:
# ...
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
#      <input type="file" id="files-3b545803-5cd3-42af-8f62-89d215ed438f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b545803-5cd3-42af-8f62-89d215ed438f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# !pip install easyocr

import easyocr
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# OCR 엔진 생성 (한국어와 영어를 지원하도록 설정)
reader = easyocr.Reader(['ko','en'])

# 이미지 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 파일명을 가져옵니다.
filename = next(iter(uploaded))

# 이미지를 읽어옵니다.
image = Image.open(filename)

# 이미지를 numpy 배열로 변환합니다.
image_np = np.array(image)

# OCR 적용
result = reader.readtext(image_np)

# 결과 출력
for res in result:
    coordinates, text, confidence = res
    print(f"Coordinates: {coordinates}")
    print(f"Text: {text}")
    print(f"Confidence: {confidence}\n")
